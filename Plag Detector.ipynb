# %% [markdown]
# # **Plagiarism Detection Checker - Application of Levenshtein Distance.**
# # **Done By:**
#
# **1. DEV VORA – 1814120**
#
# **2. JAINAM ZOBALIYA – 1814123**
#
# **3. VAIBHAVI KUNDLE – 1814127**
#
# **4. SHREYA KULKARNI – 1814129**

# %% [markdown]
# ## Firstly, We have defined a function which will calculate the levenshtein distance of the Test and Source sentences.

# %%
def leven_distance(s1, s2):
  m=len(s1)+1
  n=len(s2)+1
  mat = {}
  for i in range(m): 
    mat[i,0]=i
  for j in range(n): 
    mat[0,j]=j
  #print(tbl)
  for i in range(1, m):
    for j in range(1, n):
      if s1[i-1] == s2[j-1]:
        cost = 0 
      else:
        cost = 2
      mat[i,j] = min(mat[i, j-1]+1, mat[i-1, j]+1, mat[i-1,j-1]+cost)
  return mat[i,j]

# %% [markdown]
# ## Before calculation of levenshtein distance , we will be removing the stopwords as a step for pre-processing the sentences.

# %%
stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
def rem_stop_words(line,stopwords):
  #convert line to lowercase, split wordwise
  line_tokens = line.lower().split()
  #make a list for the word not in the stopword list
  tokens_without_sw = [word for word in line_tokens if not word in stopwords]
  new_line = " ".join(tokens_without_sw)
  return new_line

# %% [markdown]
# ## Here we have defined a function which will split the sentence line by line.
# ## We will be calculating the plagarism for each line. Accordingly the plagarism percentage will be calculated.
# ## This step can also be referred to as the tokenisation of sentences.

# %%
def para_split(line):
  line_split = line.split(". ")
  #print(line_split)
  return line_split

# %% [markdown]
# # Here we define the code to covert the results to a pdf file.
# # The font size,color and style is defined for the pdf file.

# %%
# !pip install fpdf
from fpdf import FPDF
from google.colab import files
result =""
plagArr = []
def makePDF(fileName):
  f = open(fileName, "r")
  pdf = FPDF()
  pdf.set_right_margin(100.0)
  pdf.page_no()
  pdf.set_auto_page_break(True)
  pdf.add_page()
  pdf.set_font("Times", "B" ,size = 30)
  pdf.cell(200, 10, txt = "***** Plagiarism Report *****", ln = 1, align = 'C')
  #set font for the body
  pdf.set_font("Times", size = 12)
  pdf.cell(200, 10, txt ="Note: Plagiarised Sentences are colored in red.", ln = 1, align = 'C')
  # effective_page_width = pdf.w - 3*pdf.l_margin
  for x in f:
      if x in plagArr:
        #set color for the plagiarised text
        pdf.set_text_color(255, 0, 0)
      if x == result:
        #set font size for result
        pdf.set_font("Times", "B" ,size = 18)
      pdf.multi_cell(200, 10, txt = x)
      pdf.set_text_color(0, 0, 0)
  plagArr.clear()
  pdf.output("Results.pdf")
  # files.download(fileName+'.pdf')
# Out:
# Requirement already satisfied: fpdf in /usr/local/lib/python3.7/dist-packages (1.7.2)

# %% [markdown]
# ## We will now be calling all the functions defined above for the pre-processing of the sentences. After which we will be calculating the levenshtein distance.
# ## Here, we are calculating the similarity by subtracting the ratio of Levenshtein distance and maximum length from the two strings from 1.We then multiply this value by 100 to get the similarity percentage.
# ## If this calculated similarity percentage is greater than 50% we consider the line as plagiarised.
# ## The number of sentences plagiarised is updated everytime the condition for the same is satisfied.
# ## According to the plagiarised number of lines, the plagiarism percentage is calculated.

# %%
def plagiarism_checker(Test,Source):
  sentence = ""
  sentence_1 = ""
  sentence_2 = ""
  s1_1 = para_split(Test)
  for x in range(len(s1_1)):
    sentence_1 = sentence_1 +s1_1[x]
    if s1_1[x][-1] !=".":
      sentence_1 = sentence_1 + "."
    sentence_1 = sentence_1 + "\n"
  sentence_1 = "\n"+ sentence_1
  sentence = sentence_1 + "\n"
  count = 1
  plag_count = 0
  TestArr = []
  SourceArr = []
  new_Test = rem_stop_words(Test,stopwords)
  new_Source = rem_stop_words(Source,stopwords)
  for s in para_split(new_Test) :
    TestArr.append(s)
  for s in para_split(new_Source) :
    SourceArr.append(s)
  sentence2 = ""
  for s1,s2 in zip(TestArr,SourceArr) :
    ldist = leven_distance(s1,s2) 
    maxlen = max(len(s1),len(s2))
    print()
    print("s1 is: ",s1)
    print("s2 is: ",s2)
    print("Leven: ", ldist)
    print("Max Len: ", maxlen)
    percentage_similarity = (1- (ldist/maxlen)) * 100
    # print("PS: ",percentage_similarity)
    if percentage_similarity > 50 :
      s1New = s1_1[count-1]
      s1New = s1New + ".\n"
      plagArr.append(s1New)
      print("Sentence {} is plagiarised".format(count))
      plag_count = plag_count+1
    #sentences count  
    count = count+1
  global result
  if plag_count == 0:
    s4 = "The document is 100% unique"
    sentence3 = ""
    sentence3 = sentence3 + s4 
    result = sentence3 + "\n"
    print("The document is 100% unique")
  else:
    per = (plag_count/len(SourceArr)*100)
    s5 = "The document has been detected with a Plagiarised percentage of: "
    sentence3 = ""
    sentence3 = sentence3 + s5 + str(per)+"%"
    result = sentence3 +"\n"
    print("The document has {} % of plagiarism detected".format((per)))
  sentence = sentence + sentence3 + "\n"
  return sentence

# %%
import os.path
from os import path
def menu():
  print("********WELCOME TO PLAGIARISM DETECTION TOOL**********\n")
  if (path.exists('Results.pdf')):
    # !rm Results.pdf
  choice = int(input("""
                      1: Sentence plagiarism checker
                      2: Document plagiarism checker
                      3: Download plagiarism report and Quit
                      4: Quit!
                      Please enter your choice: """))
  if choice == 1:
    source = str(input("Enter the sentence to be checked: "))
    test = str(input("Enter the sentence for comparision: "))
    sentence = plagiarism_checker(source,test)
    # write a txt file with the contents
    with open('Results.txt', 'w') as writefile:
        writefile.write(sentence)
    menu()
  elif choice == 2:
    print("Upload the first file:\n")
    from google.colab import files
    uploaded = files.upload()
    filename1 = list(uploaded.keys())
    for file in filename1:
        source = uploaded[file].decode("utf-8")
    print("Upload the second file:\n")
    from google.colab import files
    uploaded = files.upload()
    filename2 = list(uploaded.keys())
    for file in filename2:
        test = uploaded[file].decode("utf-8")
    # to avoid conversion errors.
    source.replace("-"," ")
    test.replace("-"," ")
    sentence = plagiarism_checker(source,test)
    # write a txt file with the contents
    with open('Results.txt', 'w') as writefile:
      writefile.write(sentence)
    menu()
  elif choice == 3 :
    from google.colab import files
    makePDF("Results.txt")
    files.download('Results.pdf')
  elif choice == 4 :
    print("THANK YOU")
  else:
      print("You must only select either 1 2 3 or 4")
      menu()

# %%
Test = "The First sentence is about Python. The Second: about Django. You can learn Python,Django and Data Analysis here."
Source = "The first is differenta. This second sentence is different. The third sentence is also very different."
Source2 = "The Initial sentence is not about Java. This second sentence is different. You can learn everything about anything here."
Source3 = "The Initial sentence is about Python. The Second: about Flask. You can learn Python,Django and Data manipulation here."

# %% [markdown]
# # **CASE 1:**
# ## First we will be testing same sentences against each other.
# ## This should result in a 100% plagarism.

# %%
menu()
# Out:
# ********WELCOME TO PLAGIARISM DETECTION TOOL**********
#
#
#                       1: Sentence plagiarism checker
#                       2: Document plagiarism checker
#                       3: Download plagiarism report and Quit
#                       4: Quit!
#                       Please enter your choice: 1
# Enter the sentence to be checked: The First sentence is about Python. The Second: about Django. You can learn Python,Django and Data Analysis here.
# Enter the sentence for comparision: The first is differenta. This second sentence is different. The third sentence is also very different.
#
# s1 is:  first sentence python
# s2 is:  first differenta
# Leven:  17
# Max Len:  21
#
# s1 is:  second: django
# s2 is:  second sentence different
# Leven:  21
# Max Len:  25
#
# s1 is:  learn python,django data analysis here.
# s2 is:  third sentence also different.
# Leven:  41
# Max Len:  39
# The document is 100% unique
# ********WELCOME TO PLAGIARISM DETECTION TOOL**********
#
#
#                       1: Sentence plagiarism checker
#                       2: Document plagiarism checker
#                       3: Download plagiarism report and Quit
#                       4: Quit!
#                       Please enter your choice: 4
# THANK YOU

# %% [markdown]
# # **CASE 2:**
# ## Now we will be testing two completely different sentences against each other.
# ## This should result in 100% unique.

# %%
menu()
# Out:
# ********WELCOME TO PLAGIARISM DETECTION TOOL**********
#
#
#                       1: Sentence plagiarism checker
#                       2: Document plagiarism checker
#                       3: Download plagiarism report and Quit
#                       4: Quit!
#                       Please enter your choice: 1
# Enter the sentence to be checked: The First sentence is about Python. The Second: about Django. You can learn Python,Django and Data Analysis here.
# Enter the sentence for comparision: The first is differenta. This second sentence is different. The third sentence is also very different.
# The document is 100% unique
# ********WELCOME TO PLAGIARISM DETECTION TOOL**********
#
#
#                       1: Sentence plagiarism checker
#                       2: Document plagiarism checker
#                       3: Download plagiarism report and Quit
#                       4: Quit!
#                       Please enter your choice: 4
# THANK YOU

# %% [markdown]
# # **CASE 3:**
# ## Now we will be testing two sentences ,which are having some similarity ,against each other.

# %%
menu()
# Out:
# ********WELCOME TO PLAGIARISM DETECTION TOOL**********
#
#
#                       1: Sentence plagiarism checker
#                       2: Document plagiarism checker
#                       3: Download plagiarism report and Quit
#                       4: Quit!
#                       Please enter your choice: 1
# Enter the sentence to be checked: The First sentence is about Python. The Second: about Django. You can learn Python,Django and Data Analysis here.
# Enter the sentence for comparision: The Initial sentence is not about Java. This second sentence is different. You can learn everything about anything here.
# The document is 100% unique
# ********WELCOME TO PLAGIARISM DETECTION TOOL**********
#
#
#                       1: Sentence plagiarism checker
#                       2: Document plagiarism checker
#                       3: Download plagiarism report and Quit
#                       4: Quit!
#                       Please enter your choice: 4
# THANK YOU

# %% [markdown]
# # **CASE 4:**
# ## Now we will be testing two sentences , in which only some words are replaced by other words of similar meaning , against each other.

# %%
menu()
# Out:
# ********WELCOME TO PLAGIARISM DETECTION TOOL**********
#
#
#                       1: Sentence plagiarism checker
#                       2: Document plagiarism checker
#                       3: Download plagiarism report and Quit
#                       4: Quit!
#                       Please enter your choice: 1
# Enter the sentence to be checked: The First sentence is about Python. The Second: about Django. You can learn Python,Django and Data Analysis here.
# Enter the sentence for comparision: The Initial sentence is about Python. The Second: about Flask. You can learn Python,Django and Data manipulation here.
# Sentence 1 is plagiarised
# Sentence 3 is plagiarised
# The document has 66.66666666666666 % of plagiarism detected
# ********WELCOME TO PLAGIARISM DETECTION TOOL**********
#
#
#                       1: Sentence plagiarism checker
#                       2: Document plagiarism checker
#                       3: Download plagiarism report and Quit
#                       4: Quit!
#                       Please enter your choice: 4
# THANK YOU

# %% [markdown]
# ## We now test two txt files in which the second one contains a paraphrased version of the contents from the first file.

# %%
menu()
# Out:
# ********WELCOME TO PLAGIARISM DETECTION TOOL**********
#
#
#                       1: Sentence plagiarism checker
#                       2: Document plagiarism checker
#                       3: Download plagiarism report and Quit
#                       4: Quit!
#                       Please enter your choice: 2
# Upload the first file:
#      <input type="file" id="files-40daadbf-613c-404a-9d0b-ef4cff883f4a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-40daadbf-613c-404a-9d0b-ef4cff883f4a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving case_1_new.txt to case_1_new (2).txt
# Upload the second file:
#      <input type="file" id="files-724c8126-8680-4b94-bcf6-2b7916ba20d7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-724c8126-8680-4b94-bcf6-2b7916ba20d7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving case_1 - paraphase_new.txt to case_1 - paraphase_new (2).txt
#
# s1 is:  data mining process extracting discovering patterns large data sets involving methods intersection machine learning, statistics, database systems
# s2 is:  data mining may method extracting discovering patterns giant information sets involving ways intersection machine learning, statistics, info systems
# Leven:  55
# Max Len:  148
# Sentence 1 is plagiarised
#
# s1 is:  data mining interdisciplinary subfield computer science statistics overall goal extract information (with intelligent methods) data set transform information comprehensible structure use
# s2 is:  data processing knowledge domain subfield engineering science statistics overall goal extract info (with intelligent methods) knowledge set rework knowledge understandable structure additional use
# Leven:  118
# Max Len:  196
#
# s1 is:  data mining analysis step "knowledge discovery databases" process, kdd
# s2 is:  {data mining|data methoding} analysis step "knowledge discovery databases" process, kdd
# Leven:  17
# Max Len:  87
# Sentence 3 is plagiarised
#
# s1 is:  aside raw analysis step, also involves database data management aspects, data pre-processing, model inference considerations, interestingness metrics, complexity considerations, post-processing discovered structures, visualization, online updating
# s2 is:  raw analysis step, additionally involves info information management aspects, information pre-processing, model reasoning concerns, powerfulness metrics, quality concerns, post-processing discovered structures, image, on-line change
# Leven:  127
# Max Len:  247
#
# s1 is:  term "data mining" misnomer, goal extraction patterns knowledge large amounts data, extraction (mining) data itself
# s2 is:  term "data mining" may name, result goal extraction patterns data giant amounts knowledge, extraction (mining) knowledge itself
# Leven:  56
# Max Len:  127
# Sentence 5 is plagiarised
#
# s1 is:  also buzzword frequently applied form large-scale data information processing (collection, extraction, warehousing, analysis, statistics) well application computer decision support system, including artificial intelligence (e.g., machine learning) business intelligence
# s2 is:  also bunk often applied style large-scale information information science (collection, extraction, reposition, analysis, statistics) yet application laptop call web, together computing (e.g., machine learning) business intelligence
# Leven:  134
# Max Len:  269
# Sentence 6 is plagiarised
#
# s1 is:  book data mining: practical machine learning tools techniques java (which covers mostly machine learning material) originally named practical machine learning, term data mining added marketing reasons
# s2 is:  book information mining: sensible machine learning tools techniques java (which covers principally machine learning material) originally named simply sensible machine learning, also term data processing solely selling reasons
# Leven:  87
# Max Len:  225
# Sentence 7 is plagiarised
#
# s1 is:  often general terms (large scale) data analysis analytics or, referring actual methods, artificial intelligence machine learning appropriate
# s2 is:  usually lot general terms (large scale) information analysis analytics or, touching actual ways, computing machine learning ar lot acceptable.the actual data processing task semi-automatic automatic analysis huge quantities knowledge extract antecedently unknown, fascinating patterns like teams knowledge records (cluster analysis), uncommon records (anomaly detection), dependencies (association rule mining, serial pattern mining)
# Leven:  343
# Max Len:  433
#
# s1 is:  actual data mining task semi-automatic automatic analysis large quantities data extract previously unknown, interesting patterns groups data records (cluster analysis), unusual records (anomaly detection), dependencies (association rule mining, sequential pattern mining)
# s2 is:  typically involves mistreatment info techniques like spatial indices
# Leven:  247
# Max Len:  271
#
# s1 is:  usually involves using database techniques spatial indices
# s2 is:  patterns seen sort outline computer file, employed additional analysis or, example, machine learning prognosticative analytics
# Leven:  120
# Max Len:  126
#
# s1 is:  patterns seen kind summary input data, may used analysis or, example, machine learning predictive analytics
# s2 is:  example, {the information|the info|the information} mining step may determine multiple teams within data, may wont get lot correct prediction results call web
# Leven:  159
# Max Len:  158
#
# s1 is:  example, data mining step might identify multiple groups data, used obtain accurate prediction results decision support system
# s2 is:  neither information assortment, information preparation, result interpretation reportage element information mining step, however belong general kdd method extra steps
# Leven:  175
# Max Len:  167
#
# s1 is:  neither data collection, data preparation, result interpretation reporting part data mining step, belong overall kdd process additional steps
# s2 is:  distinction information analysis data processing information analysis employed check models hypotheses dataset, e.g., analyzing effectiveness selling campaign, notwithstanding quantity data; distinction, data processing uses machine learning applied math models uncover undercover hidden patterns giant volume knowledge
# Leven:  290
# Max Len:  319
#
# s1 is:  difference data analysis data mining data analysis used test models hypotheses dataset, e.g., analyzing effectiveness marketing campaign, regardless amount data; contrast, data mining uses machine learning statistical models uncover clandestine hidden patterns large volume data.the related terms data dredging, data fishing, data snooping refer use data mining methods sample parts larger population data set (or may be) small reliable statistical inferences made validity patterns discovered
# s2 is:  connected terms information dredging, information fishing, information snooping confer employment {of information|of knowledge|of information} mining ways sample components bigger population data set ar (or might be) little reliable applied math inferences created regarding validity patterns discovered
# Leven:  406
# Max Len:  493
#
# s1 is:  methods can, however, used creating new hypotheses test larger data populations.
# s2 is:  ways will, however, employed making new hypotheses check larger information populations.
# Leven:  48
# Max Len:  88
# The document has 33.33333333333333 % of plagiarism detected
# ********WELCOME TO PLAGIARISM DETECTION TOOL**********
#
#
#                       1: Sentence plagiarism checker
#                       2: Document plagiarism checker
#                       3: Download plagiarism report and Quit
#                       4: Quit!
#                       Please enter your choice: 3

# %% [markdown]
# ## We now test two txt files in which are completely different to each other.

# %%
menu()
# Out:
# ********WELCOME TO PLAGIARISM DETECTION TOOL**********
#
#
#                       1: Sentence plagiarism checker
#                       2: Document plagiarism checker
#                       3: Download plagiarism report and Quit
#                       4: Quit!
#                       Please enter your choice: 2
# Upload the first file:
#      <input type="file" id="files-3b570378-2b50-43ff-aed1-8783a9eacd71" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3b570378-2b50-43ff-aed1-8783a9eacd71">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving case_2.txt to case_2.txt
# Upload the second file:
#      <input type="file" id="files-14ea826f-5e7b-47fb-b514-3a923c6070c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-14ea826f-5e7b-47fb-b514-3a923c6070c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving case_3.txt to case_3.txt
# The document is 100% unique
# ********WELCOME TO PLAGIARISM DETECTION TOOL**********
#
#
#                       1: Sentence plagiarism checker
#                       2: Document plagiarism checker
#                       3: Download plagiarism report and Quit
#                       4: Quit!
#                       Please enter your choice: 3
